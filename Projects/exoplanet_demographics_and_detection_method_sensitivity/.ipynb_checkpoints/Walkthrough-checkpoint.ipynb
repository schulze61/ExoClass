# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sp
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

import sys
import os
sys.path.insert(0, os.path.abspath('./functions'))

from functions import lc_model

data = pd.read_csv("./data/PS_2026.07.24_07.42.56.csv", comment = '#')

# %% [markdown]
# ## Overview
# Your job for this project is to approximate the detection limits for four exoplanet detection techniques we have discussed in detail: radial velocity, transit photometry, astrometry, direct imaging. In particular, you will create functions that approximate the *minimum*, or lowest, detectable exoplanet mass ($M_{p, min}$) or radius ($R_{p, min}$) as a function of exoplanet orbital period ($P$) and semi-major axis ($a$).
#
# You will overlay your calculated detection limits on the following plots, **as applicable**, on $M_p-P$, $M_p-a$, $R_p-P$, and $R_p-a$ plots. You will need to include **all** currently known planets and exoplanets, and discuss how our knowledge of (exo)planetary demographics is heavily shaped by what we can actually detect. You should highlight and discuss **all** of the exoplanets from the previous *Detection Techniques* project.

# %% [markdown]
# ## Part 1: calculate the limits of detection techniques
# Below, you are provided you the fundamental equation(s) you will need to calculate the limits for the five detection techniques assigned in this project. Also, included are short descriptions of what we  For **each** technique:
#
# 1. Pick **one** "state-of-the-art" instrument/survey. You will need to be able to defend your choice. For this part of the project, stick to instruments that have been doing science for a number of years. For example, do not pick ROMAN for gravitational microlensing.
# 2. Comb the literature to find the appropriate detection limits. For example, for astrometry you will need to determine your instruments minimum resolvable $\Theta$.
# 3. Make some reasonable assumptions about the non-exoplanet parameters (e.g., $M_\star$, $R_\star$, $d$ in the equations you are given below). You will need to be able to explain and defend these assumptions.
#
#
# ### Astrometry
# $\LARGE \theta = \frac{M_p}{M_\star}\frac{a}{d}$
#
# GRAVITY: https://www.eso.org/public/teles-instr/paranal-observatory/vlt/vlt-instr/gravity/
#
# GAIA: https://sci.esa.int/web/gaia/-/31365-astrometry
#
#
# ### Radial Velocity
#  $\LARGE K = \frac{M_p}{M_\star}\cdot\sqrt{\frac{GM_\star}{a}}\cdot\sin i$
#
#  ESPRESSO: https://www.eso.org/sci/facilities/paranal/instruments/espresso.html
#
#  EXPRES: https://lowell.edu/research/telescopes-and-facilities/ldt/extreme-precision-spectrometer-expres/
#
#  HARPS: https://www.eso.org/public/teles-instr/lasilla/36/harps/
#
#  PEPSI: https://pepsi.aip.de/
#
#  KPF: https://www2.keck.hawaii.edu/inst/kpf/
#
#  ### Direct imaging
# Ignore reflected light and focus on the thermal emission contribution. Pick some logical values for $T_\star$ and $T_p$ and keep them fixed for your analysis.
#
#  $\LARGE f = \left(\frac{R_p}{R_\star}\right)^2 \frac{\exp(h\nu / k_b T_\star) - 1}{\exp(h\nu / k_b T_p) - 1}$
#
#  $\LARGE \theta_{min} = 1.22\frac{\lambda}{D}$
#
#  Gemini Planet Imager: http://planetimager.org/
#
#  SPHERE: https://www.eso.org/public/teles-instr/paranal-observatory/vlt/vlt-instr/sphere/
#
#
#
#  ### Transit photometry
#
# $\LARGE \delta = \left(\frac{R_p}{R_\star} \right)^2$
#
# Kepler and K2: https://science.nasa.gov/mission/kepler/
#
# TESS: https://tess.mit.edu/

# %% [markdown]
# ### Demo for Part 1: transit photometry
#
# This example is intended to give you an idea of roughly how involved your group's analysis should be for each technique. You are welcome to use this example as a template for your own analysis for the transit photometry method. If you do so, you are still responsible for being able to explain and defend each step. Further, this approach represent the bare minimum amount of analysis expected of you for estimating the limits of the transit photometry exoplanet detection technique. It is not the only approach you can take, and it is certainly not the best or most robust approximation.

# %% [markdown]
# ##### Minimum detectable exoplanet radii

# %% [markdown]
# Say we consider a transiting planet to be conclusively detected when it has a signal-to-noise ratio (SNR) of 3 or greater (the higher the SNR, the more confident we are that the signal is real). This means that the transit depth $\delta$ must be $\geq 3\times$ the noise floor of our detector (i.e., the uncertainty in each data point).
#
# Here, let's adopt a detector noise floor of 20 ppm, meaning $\delta_{min} = 60$ ppm or $\delta_{min} = 60\times10^{-6}$ for a positive exoplanet detection. You will need to research the state-of-the-art instruments to find your own value for the noise (and cite your source!), but it should be similar-ish to the value I'm using.
#
# The figure below illustrates this concept for $\delta = 0\times$noise (i.e., just the noise of our detector), $\delta = 1\times$noise (no detection), $\delta = 3\times$noise (minimum criteria for conclusive detection), $\delta = 5\times$noise (strong detection).

# %%
SNR = [0.0, 1.0, 3.0, 5.0] #signal-to-noise ratio
num_measurements = 200
noise = 20*(10**(-6))

yticks = np.linspace(-500, 500, 41)

fig, ax = plt.subplots(1,len(SNR), figsize = (len(SNR)*5,5))

for i in np.arange(0, len(SNR))[::-1]:
    normalized_flux_without_planet = sp.norm.rvs(1.0, noise, size = num_measurements)
    lc_truth, orb_phase = lc_model(SNR[i]*noise, npts = num_measurements)
    normalized_flux_with_planet = lc_truth + sp.norm.rvs(0.0, noise, num_measurements)

    delta_flux_with_planet = (normalized_flux_with_planet-1)/(10**(-6)) #in ppm
    delta_flux_without_planet = (normalized_flux_without_planet-1)/(10**(-6))
    ax[i].plot(orb_phase, delta_flux_with_planet , 'ko', markersize = 5, label = 'w/ exoplanet')
    ax[i].plot(orb_phase, delta_flux_without_planet , 'ro', alpha = 0.3, markersize = 5, label = 'w/o exoplanet')

    if i == len(SNR)-1:
        yrange = [0.99*min(delta_flux_with_planet), 1.01*max(delta_flux_with_planet)]
        
    ax[i].set_title(f"$\delta = {int(SNR[i])}$" + r'$\times$' + f'{noise/(10**(-6)):.0f} ppm' + '\n' + f'SNR = {SNR[i]:.0f}', fontsize = 16)
    ax[i].set_ylim(yrange)
    ax[i].patch.set_edgecolor('black')  
    ax[i].patch.set_linewidth(2)  
    ax[i].tick_params(which = 'major', axis = 'x', direction = 'in', length = 10, top = True,  right = True, width = 2, labelsize = 16)
    ax[i].tick_params(which = 'minor', direction = 'in',length = 7,  top = True,  right = True, width = 2)
    if i != 0:
        ax[i].tick_params(which = 'major', axis = 'y', direction = 'in', length = 10, top = True,  right = True, width = 2, labelsize = 0)
    else:
        ax[i].tick_params(which = 'major', axis = 'y', direction = 'in', length = 10, top = True,  right = True, width = 2, labelsize = 16)
        ax[i].set_ylabel(r'$\Delta$Flux (ppm)', fontsize = 20)
        ax[i].legend(fontsize = 16)

        
    ax[i].set_xlabel(r'Orbital Phase', fontsize = 20)
    ax[i].xaxis.set_major_locator(MultipleLocator(0.001))
    ax[i].xaxis.set_minor_locator(MultipleLocator(0.00025))
    ax[i].yaxis.set_major_locator(MultipleLocator(25))
    ax[i].yaxis.set_minor_locator(MultipleLocator(5))

plt.tight_layout()

# %% [markdown]
# OK, great, we have a minimum $\delta$ value that is required for us to consider an exoplanet "detected". But what we *REALLY* want to know is the minimum detectable $R_p$. Solving the $\delta$ equation for planet radius gives
#
# $$\LARGE R_p = \sqrt{\delta}R_\star$$
#
# subbing in $\delta_{min}$ gives the minimum detectable planet radius
#
# $$\LARGE R_{p,min} = \sqrt{\delta_{min}}R_\star = \sqrt{60\times10^{-6}} R_\star \sim 0.008 R_\star$$
#
# What should we use for $R_\star$? Again, this is up to you and your group. You will need to make a logical assumption about $R_\star$ (you can also assume a range of $R_\star$ if you are so inclined). For the sake of this demo, let's adopt $R_\star = 1 R_\odot$. Why? If we look at the mean $R_\star$ for planets detected via the transit method, we get an average value that is effectively equal to 1$R_\odot$:

# %%
ind = np.where((data['discoverymethod'] == 'Transit') & (np.isnan(data['st_rad']) == False))

print('Mean R_star for planets discovered via transit photometry: ', np.mean(data['st_rad'].iloc[ind]))
# Out:
# Mean R_star for planets discovered via transit photometry:  1.0066546488533104

# %% [markdown]
# If we wanted to be less sensitive to large stars in our analysis, what statistic would have been a better choice?
#
# Anyway, now that we have a characteristic values for $R_\star$, we can write
#
# $$\LARGE R_{p,min} \sim 0.008\times R_\odot = 0.008\times 109 R_\oplus \sim 0.9R_\oplus$$

# %% [markdown]
# ##### Maximum exoplanet orbital period / semi-major axis
# So we have $R_{p, min}$, but this, of course, exoplanet size is not the only limitation of the transit photometry method. To simply discussion for now, let's consider a single system with 1 star and 1 transiting exoplanet with an orbital period of $P$ days. As we have discussed earlier in the course, the transit of the exoplanet will most likely be very short in duration relative to its $P$. So, if we don't have a good idea of when the exoplanet will transit, if we observe the star for any $t<P$, we are likely to miss the transit and miss our opportunity to measure $R_p$.
#
# Let's generalize this now. We know that the majority of known transiting exoplanets were discovered by the Kepler mission. So, let's use this as our baseline for determining the approximate maximimum $P$ below which we should be able to detect exoplanets reliably.

# %%
print('Frac of transiting planets detected by Kepler = ', str(round(len(np.where(data['disc_facility'] == 'Kepler')[0])/len(np.where(data['discoverymethod'] == 'Transit')[0]), 2)))
# Out:
# Frac of transiting planets detected by Kepler =  0.6

# %% [markdown]
# The primary mission of Kepler stared at the same field of view (i.e., the same patch of sky and the same sample of stars) for about 3 years. This means that the planets detected by Kepler would have been limited to orbital periods of $\lesssim 3$ years. Why?

# %% [markdown]
# ## Part 2: use the NASA exoplanet archive (NEA) to generate $M_p-P$, $M_p-a$, $R_p-P$, and $R_p-a$ figures and overlay your calculated limits for each detection technique.
#
# Below is an example of these plots to give you an idea of what we are looking for. I'm showing the detection limits we calculated in the demo above for transit photometry: $R_p \gtrsim 0.9 R_\oplus$ **AND** $P \lesssim 3$ years. You and your group will need to make your own versions of these figures that include limits for **ALL** of the detection techniques listed in Part 1. You should color code the exoplanets by their discovery method so that it is easy to compare, e.g., transiting exoplanets with your calculated limits for the transit method.

# %%
fig, ax = plt.subplots(2,2, figsize = (10,10))

ind_transit = np.where(data['discoverymethod'] == 'Transit')[0]
ind_rv = np.where(data['discoverymethod'] == 'Radial Velocity')[0]
ind_imaging = np.where(data['discoverymethod'] == 'Imaging')[0]
ind_astrometry = np.where(data['discoverymethod'] == 'Astrometry')[0]

ax[0,0].plot(data["pl_orbper"].iloc[ind_transit], data["pl_rade"].iloc[ind_transit], "gs", fillstyle = 'none', alpha = 0.5, label = 'Transit')
ax[0,0].plot(data["pl_orbper"].iloc[ind_rv], data["pl_rade"].iloc[ind_rv], "ro", fillstyle = 'none', alpha = 1.0, label = 'RV')
ax[0,0].plot(data["pl_orbper"].iloc[ind_astrometry], data["pl_rade"].iloc[ind_astrometry], "o", color = 'gray', alpha = 1.0, label = 'Astrometry')
ax[0,0].plot(data["pl_orbper"].iloc[ind_imaging], data["pl_rade"].iloc[ind_imaging], "b*", alpha = 1.0, label = 'D.I.')
ax[0,0].plot([min(data['pl_orbper']), 3.0*365], [0.9, 0.9], 'k-', lw = 2)
ax[0,0].plot([3.0*365, 3.0*365], [0.9, 100], 'k-', lw = 2)
ax[0,0].set_ylim(0.2, 100.0)
ax[0,0].set_xlim(0.1, 10**9)


ax[0,0].legend(fontsize = 14, frameon = False)

ax[0,0].set_xscale("log")
ax[0,0].set_yscale("log")
ax[0,0].set_xlabel("Period [days]", fontsize = 18)
ax[0,0].set_ylabel(r"Radius [R$_\oplus$]", fontsize = 18)


ax[0,1].plot(data["pl_orbsmax"].iloc[ind_transit], data["pl_rade"].iloc[ind_transit], "gs", fillstyle = 'none', alpha = 0.5)
ax[0,1].plot(data["pl_orbsmax"].iloc[ind_rv], data["pl_rade"].iloc[ind_rv], "ro", fillstyle = 'none', alpha = 1.0)
ax[0,1].plot(data["pl_orbsmax"].iloc[ind_astrometry], data["pl_rade"].iloc[ind_astrometry], "o", color = 'gray', alpha = 1.0)
ax[0,1].plot(data["pl_orbsmax"].iloc[ind_imaging], data["pl_rade"].iloc[ind_imaging], "b*", alpha = 1.0)


ax[0,1].plot([(min(data['pl_orbper'])/365)**(2.0/3.0), 3.0**(2.0/3.0)], [0.9, 0.9], 'k-')
ax[0,1].plot([3.0**(2.0/3.0), 3.0**(2.0/3.0)], [0.9, 100], 'k-')

ax[0,1].set_xscale("log")
ax[0,1].set_yscale("log")
ax[0,1].set_xlabel("a [au]", fontsize = 18)
ax[0,1].set_ylabel(r"Radius [R$_\oplus$]", fontsize = 18)
ax[0,1].set_ylim(0.2, 100.0)
ax[0,1].set_xlim(0.003, 10**5)



ax[1,0].plot(data["pl_orbper"].iloc[ind_transit], data["pl_bmasse"].iloc[ind_transit], "gs", fillstyle = 'none', alpha = 0.5)
ax[1,0].plot(data["pl_orbper"].iloc[ind_rv], data["pl_bmasse"].iloc[ind_rv], "ro", fillstyle = 'none', alpha = 0.5)
ax[1,0].plot(data["pl_orbper"].iloc[ind_astrometry], data["pl_bmasse"].iloc[ind_astrometry], "o", color = 'gray', alpha = 1.0)
ax[1,0].plot(data["pl_orbper"].iloc[ind_imaging], data["pl_bmasse"].iloc[ind_imaging], "b*", alpha = 1.0)

ax[1,0].set_xscale("log")
ax[1,0].set_yscale("log")
ax[1,0].set_xlabel("Period [days]", fontsize = 18)
ax[1,0].set_ylabel(r"Mass [M$_\oplus$]", fontsize = 18)
ax[1,0].set_xlim(0.1, 10**9)


ax[1,1].plot(data["pl_orbsmax"].iloc[ind_transit], data["pl_bmasse"].iloc[ind_transit], "gs", fillstyle = 'none', alpha = 0.5)
ax[1,1].plot(data["pl_orbsmax"].iloc[ind_rv], data["pl_bmasse"].iloc[ind_rv], "ro", fillstyle = 'none', alpha = 0.5)
ax[1,1].plot(data["pl_orbsmax"].iloc[ind_astrometry], data["pl_bmasse"].iloc[ind_astrometry], "o", color = 'gray', alpha = 1.0)
ax[1,1].plot(data["pl_orbsmax"].iloc[ind_imaging], data["pl_bmasse"].iloc[ind_imaging], "b*", alpha = 1.0)

ax[1,1].set_xscale("log")
ax[1,1].set_yscale("log")
ax[1,1].set_xlabel("a [au]", fontsize = 18)
ax[1,1].set_ylabel(r"Mass [M$_\oplus$]", fontsize = 18)
ax[1,1].set_xlim(0.003, 10**5)


ax[0,0].tick_params(which = 'major', top = True, right = True, labelsize = 12, length = 10, direction = 'in')
ax[0,0].tick_params(which = 'minor', top = True, right = True, labelsize = 12, length = 5, direction = 'in')

ax[0,1].tick_params(which = 'major', top = True, right = True, labelsize = 12, length = 10, direction = 'in')
ax[0,1].tick_params(which = 'minor', top = True, right = True, labelsize = 12, length = 5, direction = 'in')

ax[1,0].tick_params(which = 'major', top = True, right = True, labelsize = 12, length = 10, direction = 'in')
ax[1,0].tick_params(which = 'minor', top = True, right = True, labelsize = 12, length = 5, direction = 'in')

ax[1,1].tick_params(which = 'major', top = True, right = True, labelsize = 12, length = 10, direction = 'in')
ax[1,1].tick_params(which = 'minor', top = True, right = True, labelsize = 12, length = 5, direction = 'in')


ax[0,0].patch.set_edgecolor('black')  
ax[0,0].patch.set_linewidth(2)  
ax[0,0].tick_params(which = 'major', direction = 'in', length = 10, top = True,  right = True, width = 2, labelsize = 16)
ax[0,0].tick_params(which = 'minor', direction = 'in',length = 7,  top = True,  right = True, width = 1)

ax[0,1].patch.set_edgecolor('black')  
ax[0,1].patch.set_linewidth(2)  
ax[0,1].tick_params(which = 'major',  direction = 'in', length = 10, top = True,  right = True, width = 2, labelsize = 16)
ax[0,1].tick_params(which = 'minor', direction = 'in',length = 7,  top = True,  right = True, width = 2)

ax[1,0].patch.set_edgecolor('black')  
ax[1,0].patch.set_linewidth(2)  
ax[1,0].tick_params(which = 'major',  direction = 'in', length = 10, top = True,  right = True, width = 2, labelsize = 16)
ax[1,0].tick_params(which = 'minor', direction = 'in',length = 7,  top = True,  right = True, width = 2)

ax[1,1].patch.set_edgecolor('black')  
ax[1,1].patch.set_linewidth(2)  
ax[1,1].tick_params(which = 'major', direction = 'in', length = 10, top = True,  right = True, width = 2, labelsize = 16)
ax[1,1].tick_params(which = 'minor', direction = 'in',length = 7,  top = True,  right = True, width = 2)

from matplotlib import ticker as mticker
#ax[0,0].xaxis.set_major_locator(mticker.LogLocator(numticks=999))
ax[0,0].xaxis.set_minor_locator(mticker.LogLocator(numticks=999, subs="auto"))

plt.tight_layout()

# %% [markdown]
# ### Despite the huge simplifying assumptions we made in this demo, our detection limits for the transit method look pretty good, eh?

# %% [markdown]
# ## Part 3: interpreting the broader picture

# %% [markdown]
# For this part of the project, it's time to take a step back and work to understand how our knowledge of exoplanet demographics are shaped by what we have actually observed. While we can make physically motivated guesses about as-of-yet unobserved types of exoplanets, until we actually observe them it remains guesswork. Here we will use the (exo)planets we know best as anchors: the 8 Solar System planets and the 4 exoplanets from the previous project (GJ 1214 b, HD 189733 b, TOI-2109 b, or GJ 486 b). To this end, overlay and highlight the Solar System planets and ALL four exoplanets from the previous project on your figues. In other words, these 12 objects should be easily distinguishable from the rest of ~6,000 exoplanets.
#
# For **EACH DETECTION METHOD**, calculate the observational signal for the 8 Solar System planets and the 4 project #1 exoplanets. Then answer and discuss the following questions with your group:
# - which of these 8 Solar System planets and 4 exoplanets are detectable with this technique? Why?
# - which of these 8 Solar System planets and 4 exoplanets are NOT detectable with this technique? Why?
# - more generally, what exoplanetary insights would we potentially have missed out on without this particular detection technique?

# %% [markdown]
# ## Part 4: choose your own adventure!!

# %% [markdown]
# For this part of the project, the minimum expectation is that either (1) you will do a more in-depth / robust / realistic version of Part 1 for ONE of the detection techniques, or (2) do the project again for an additional technique (e.g., microlensing). Here are some ideas to get you started:
#
# ### Transit photometry:
# - Idea 1: Use the transit probability to estimate the actual number of planets as a function of orbital distance. Our sample of transiting planets is incomplete because of the transit probability: as semi-major axis increases the number of planets we detect decreases b/c they are less likely to transit. Plot a histogram of number of transiting planets as a function of orbital distance. Renomarlize this using the tranist probability and overlay the results on your histogram.
# - Idea 2: the transit photometry example for Part 1 implicitly assumes that we only detect one transit per planet. Kepler stared at the same patch of sky for ~3 years meaning it would have detected ~1000 transits for planets with 1 day orbital periods, 100 for 10 day orbital periods, and so on. You can stack or average over multiple transits to get a higher signal to noise given. The signal to noise over multiple transits for Kepler is approximately (from https://iopscience.iop.org/article/10.1088/0067-0049/201/2/15/pdf)
#
# $$\large SNR = \frac{\delta}{\sigma_{CDPP}} \sqrt{\frac{n_{tr} \cdot t_{dur}}{3 hr}}$$
#
# Use this equation to derive a period-dependent transit photometry detection limit. $\sigma_{CDPP}$ is actually a star specific term. Just assume a optimistic single value of 30 ppm for it.
#
# ### Direct imaging:
# - idea 1: Look up how to calculate the equilibrium temperature of a planet as a function of its orbital distance. Use this to investigate how the minimum detectable planet radius changes as a function of semi-major axis for direct imaging.
# - idea 2: Repeat Part 1 but for reflected light. Add this to your plots and discuss the difference in the detection limits between reflected and thermally emitted light.
#
# ### For any of the techniques:
# - idea 1: do a sensitivity analysis for $R_\star$ and $M_\star$ and use the NASA exoplanet archive. Basially, answer: do the detection limits for each method depend on star-type?
# - idea 2: Repeat part 1 for a relatively new mission (e.g., TESS for transit photometry). Plot it and discuss what information you expect it to add to our understanding of exoplanet demographics.

# %% [markdown]
# ### Appendix -- Something that may make your life a bit easier
# ![keps_3rd_law_simplification.png](attachment:keps_3rd_law_simplification.png)
